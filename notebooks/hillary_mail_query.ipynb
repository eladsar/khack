# %% [markdown]
# # Hillary Email Query

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../code')
sys.path.append('../code/contriever-main')
sys.path.append('../code/contriever-main/src')

from hillary_mails import HillaryQueryScore
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Some weights of the model checkpoint at facebook/contriever were not used when initializing Contriever: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing Contriever from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Contriever from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## Model load

# %%
hqs = HillaryQueryScore()

# %% [markdown]
# ## Queries

# %%
query = 'Benghazi attack'

query_scores = hqs.get_query_scores(query)
query_scores[:10]
# Out:
#       DocNumber                                            RawText  \
# 2373  C05739826  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2028  C05739798  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1788  C05739757  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 36    C05739560  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 502   C05739623  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 567   C05739629  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 534   C05739627  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 446   C05739615  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
# 465   C05739618  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 484   C05739620  UNCLASSIFIED\nU.S. Department of State\nCase N...
#
#                                              paragraphs  \
# 2373  on the successful Benghazi attack, or launchin...
# 2028  Libyans march against Islamist militias in Ben...
# 1788  Libyans march against Islamist militias in Ben...
# 36    Ambassador J. Christopher Stevens and three ot...
# 502    Libya attack to paint Obama as weak on terrorism
# 567    Libya attack to paint Obama as weak on terrorism
# 534    Libya attack to paint Obama as weak on terrorism
# 446    Libya attack to paint Obama as weak on terrorism
# 465    Libya attack to paint Obama as weak on terrorism
# 484    Libya attack to paint Obama as weak on terrorism
#
#                                               embedding     score
# 2373  [-0.030353069305419922, -0.032487206161022186,...  0.721530
# 2028  [0.03709092363715172, -0.00034611611044965684,...  0.704742
# 1788  [0.03709092363715172, -0.00034611611044965684,...  0.704742
# 36    [-0.019471045583486557, -0.07690425217151642, ...  0.689470
# 502   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 567   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 534   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 446   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 465   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 484   [-0.03538616746664047, -0.011815848760306835, ...  0.673741

# %%
query = 'health care issues'

query_scores = hqs.get_query_scores(query)
query_scores[:10]
# Out:
#        DocNumber                                            RawText  \
# 18974  C05766224  UNCLASSIFIED U.S. Department of State Case No....
# 30737  C05770985  B6\nUNCLASSIFIED U.S. Department of State Case...
# 35022  C05772611  UNCLASSIFIED U.S. Department of State Case No....
# 23970  C05768033  UNCLASSIFIED U.S. Department of State Case No....
# 38855  C05774350  UNCLASSIFIED U.S. Department of State Case No....
# 30745  C05770985  B6\nUNCLASSIFIED U.S. Department of State Case...
# 34850  C05772611  UNCLASSIFIED U.S. Department of State Case No....
# 17745  C05765692  UNCLASSIFIED U.S. Department of State Case No....
# 17731  C05765689  UNCLASSIFIED U.S. Department of State Case No....
# 5829   C05760390  UNCLASSIFIED U.S. Department of State Case No....
#
#                                               paragraphs  \
# 18974               including the health care fight, the
# 30737               to deliver a health care reform bill
# 35022               policy makers, advocates, and health
# 23970  We all think you should do, the timing allows ...
# 38855  We all think you should do, the timing allows ...
# 30745               health care. I don't think so." (His
# 34850              have policies on health, but only the
# 17745  Just a brief update on the Senate health care ...
# 17731  Just a brief update on the Senate health care ...
# 5829   Just a brief update on the Senate health care ...
#
#                                                embedding     score
# 18974  [-0.045833002775907516, 0.027074526995420456, ...  0.621586
# 30737  [-0.03793305158615112, 0.03578798472881317, -0...  0.539725
# 35022  [-0.07717327028512955, -0.09783484041690826, 0...  0.534508
# 23970  [-0.06553936004638672, -0.004795410204678774, ...  0.513699
# 38855  [-0.06553936004638672, -0.004795410204678774, ...  0.513699
# 30745  [-0.03156497702002525, -0.02999492548406124, 0...  0.506613
# 34850  [-0.10943390429019928, -0.0031704814173281193,...  0.497036
# 17745  [0.0007359510636888444, -0.017547864466905594,...  0.491792
# 17731  [0.0007359510636888444, -0.017547864466905594,...  0.491792
# 5829   [0.0007359510636888444, -0.017547864466905594,...  0.491792

# %%
query = 'Israel economy'

query_scores = hqs.get_query_scores(query)
query_scores[:10]
# Out:
#        DocNumber                                            RawText  \
# 25221  C05768705  UNCLASSIFIED U.S. Department of State Case No....
# 25218  C05768704  UNCLASSIFIED U.S. Department of State Case No....
# 16999  C05764988  UNCLASSIFIED U.S. Department of State Case No....
# 6465   C05760648  UNCLASSIFIED U.S. Department of State Case No....
# 14126  C05763811  UNCLASSIFIED U.S. Department of State Case No....
# 10025  C05762336  UNCLASSIFIED U.S. Department of State Case No....
# 30619  C05770951  UNCLASSIFIED U.S. Department of State Case No....
# 32542  C05771654  UNCLASSIFIED U.S. Department of State Case No....
# 33014  C05771854  UNCLASSIFIED U.S. Department of State Case No....
# 32127  C05771514  UNCLASSIFIED U.S. Department of State Case No....
#
#                                               paragraphs  \
# 25221             Israeli-Palestinian Peace Negotiations
# 25218             Israeli-Palestinian Peace Negotiations
# 16999      At the Second Israeli Presidential Conference
# 6465       At the Second Israeli Presidential Conference
# 14126  The International Monetary Fund reported Wedne...
# 10025              By Barak Ravid, Haaretz Correspondent
# 30619  The direct negotiations between Israel and the...
# 32542  for statehood, and that Abu Mazen's economic a...
# 33014  for statehood, and that Abu Mazen's economic a...
# 32127  With settlement deal, U.S. will be rewarding I...
#
#                                                embedding     score
# 25221  [-0.011888442561030388, -0.023315617814660072,...  0.603100
# 25218  [-0.011888442561030388, -0.023315617814660072,...  0.603100
# 16999  [-0.10526689887046814, -0.00634505320340395, -...  0.602127
# 6465   [-0.10526689887046814, -0.00634505320340395, -...  0.602127
# 14126  [-0.11489581316709518, -0.022856181487441063, ...  0.593022
# 10025  [-0.03044387511909008, -0.009761754423379898, ...  0.582741
# 30619  [-0.033894795924425125, -0.0107504203915596, -...  0.578438
# 32542  [-0.1291784942150116, -0.08671676367521286, -0...  0.565083
# 33014  [-0.1291784942150116, -0.08671676367521286, -0...  0.565083
# 32127  [-0.11266020685434341, 0.01710311509668827, -0...  0.560479
