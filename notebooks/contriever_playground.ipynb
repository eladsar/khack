# %% [markdown]
# # Contriever - Playground

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
from tqdm import trange, tqdm
from bs4 import BeautifulSoup

import sys
sys.path.append('../code')
sys.path.append('../code/contriever-main')
sys.path.append('../code/contriever-main/src')

from contriever_utils import calc_contriever_score, get_contriever_embedding, mail_raw_text2paragraphs
from hillary_mails import HillaryEmails, HillaryQueryScore
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load model and tokenizer

# %%
from src.contriever import Contriever
from transformers import AutoTokenizer

contriever = Contriever.from_pretrained("facebook/contriever") 
tokenizer = AutoTokenizer.from_pretrained("facebook/contriever") #Load the associated tokenizer:
# Out:
# Some weights of the model checkpoint at facebook/contriever were not used when initializing Contriever: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing Contriever from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Contriever from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
slat_text = " Salt is a mineral composed primarily of sodium chloride (NaCl), a chemical compound belonging to the larger class of salts; salt in the form of a natural crystalline mineral is known as rock salt or halite. Salt is present in vast quantities in seawater. The open ocean has about 35 g (1.2 oz) of solids per liter of sea water, a salinity of 3.5%. Salt is essential for life in general, and saltiness is one of the basic human tastes. Salt is one of the oldest and most ubiquitous food seasonings, and is known to uniformly improve the taste perception of food, including otherwise unpalatable food.[1] Salting, brining, and pickling are also ancient and important methods of food preservation. Some of the earliest evidence of salt processing dates to around 6,000 BC, when people living in the area of present-day Romania boiled spring water to extract salts; a salt-works in China dates to approximately the same period. Salt was also prized by the ancient Hebrews, Greeks, Romans, Byzantines, Hittites, Egyptians, and Indians. Salt became an important article of trade and was transported by boat across the Mediterranean Sea, along specially built salt roads, and across the Sahara on camel caravans. The scarcity and universal need for salt have led nations to go to war over it and use it to raise tax revenues. Salt is used in religious ceremonies and has other cultural and traditional significance. Salt is processed from salt mines, and by the evaporation of seawater (sea salt) and mineral-rich spring water in shallow pools. The greatest single use for salt (sodium chloride) is as a feedstock for the production of chemicals.[2] It is used to produce caustic soda and chlorine; it is also used in the manufacturing processes of polyvinyl chloride, plastics, paper pulp and many other products. Of the annual global production of around three hundred million tonnes of salt, only a small percentage is used for human consumption. Other uses include water conditioning processes, de-icing highways, and agricultural use. Edible salt is sold in forms such as sea salt and table salt which usually contains an anti-caking agent and may be iodised to prevent iodine deficiency. As well as its use in cooking and at the table, salt is present in many processed foods. Sodium is an essential nutrient for human health via its role as an electrolyte and osmotic solute.[3][4][5] Excessive salt consumption may increase the risk of cardiovascular diseases, such as hypertension, in children and adults. Such health effects of salt have long been studied. Accordingly, numerous world health associations and experts in developed countries recommend reducing consumption of popular salty foods.[5][6] The World Health Organization recommends that adults consume less than 2,000 mg of sodium, equivalent to 5 grams of salt per day"

# %%
sentences = [
    "Where was Marie Curie born?",
    "Maria Sklodowska, later known as Marie Curie, was born on November 7, 1867.",
    "Born in Paris on 15 May 1859, Pierre Curie was the son of Eugène Curie, a doctor of French Catholic origin from Alsace.",
    slat_text,
    "diagestible product"
]

model = contriever
inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
embeddings = model(**inputs)

# %%
inputs.keys()
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])

# %%
embeddings
# Out:
# tensor([[-0.0209, -0.0018, -0.0142,  ...,  0.0633, -0.0633, -0.0476],
#         [-0.0803,  0.0197, -0.0279,  ..., -0.0004, -0.0683, -0.0378],
#         [-0.0471, -0.0310, -0.0315,  ...,  0.0225,  0.0133, -0.0278],
#         [ 0.0935,  0.0421,  0.0112,  ...,  0.0324, -0.0065,  0.0623],
#         [-0.0451, -0.0315, -0.0090,  ..., -0.0232,  0.0295, -0.0788]],
#        grad_fn=<DivBackward0>)

# %%
score01 = embeddings[0] @ embeddings[1] #1.0473
score02 = embeddings[0] @ embeddings[2] #1.0095
score03 = embeddings[0] @ embeddings[3] #1.0095

# %%
score01
# Out:
# tensor(1.0473, grad_fn=<DotBackward0>)

# %%
score02
# Out:
# tensor(1.0095, grad_fn=<DotBackward0>)

# %%
score03
# Out:
# tensor(0.4666, grad_fn=<DotBackward0>)

# %%
score01 = embeddings[4] @ embeddings[1] #1.0473
score02 = embeddings[4] @ embeddings[2] #1.0095
score03 = embeddings[4] @ embeddings[3] #1.0095
print(f"score01 = {score01}")
print(f"score02 = {score02}")
print(f"score03 = {score03}")
# Out:
# score01 = 0.45287925004959106
# score02 = 0.420390784740448
# score03 = 0.7001084685325623

# %%
np.linalg.norm(embeddings[3].detach().numpy())
# Out:
# 1.82967

# %% [markdown]
# ## TechCrunch Scrappings

# %%
paragraphs_path = '/home/ron/projects/contriever/notebooks/techcrunch_paragraphs21.fea'

paragraphs = pd.read_feather(paragraphs_path)
paragraphs
# Out:
#       index                                                url  \
# 0         0  https://techcrunch.com/2023/01/31/snapchat-now...
# 1         0  https://techcrunch.com/2023/01/31/snapchat-now...
# 2         0  https://techcrunch.com/2023/01/31/snapchat-now...
# 3         0  https://techcrunch.com/2023/01/31/snapchat-now...
# 4         0  https://techcrunch.com/2023/01/31/snapchat-now...
# ...     ...                                                ...
# 3869    312  https://techcrunch.com/2023/01/12/career-karma...
# 3870    312  https://techcrunch.com/2023/01/12/career-karma...
# 3871    312  https://techcrunch.com/2023/01/12/career-karma...
# 3872    312  https://techcrunch.com/2023/01/12/career-karma...
# 3873    312  https://techcrunch.com/2023/01/12/career-karma...
#
#                                               paragraph
# 0     Snapchat has more than 2 million paid subscrib...
# 1     The social network first launched Snapchat+ in...
# 2     Snap was able to attract a million subscribers...
# 3     Snapchat+ offers users features like the abili...
# 4     In the last quarter, the company introduces ne...
# ...                                                 ...
# 3869  “Last year, we made the decision to right-size...
# 3870  During Career Karma’s last cut, Harris emphasi...
# 3871  As TechCrunch has discussed in the past, the s...
# 3872  With 80 staff now remaining at Career Karma, H...
# 3873  Current and former Career Karma employees can ...
#
# [3874 rows x 3 columns]

# %%
batch_size = 100
embeddings = []

for i in trange(0, len(paragraphs), batch_size):
    embeddings += get_contriever_embedding(paragraphs.iloc[i:i+batch_size]['paragraph'])
# Out:
# Some weights of the model checkpoint at facebook/contriever were not used when initializing Contriever: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing Contriever from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Contriever from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100% 13/13 [01:12<00:00,  5.56s/it]

# %%
paragraphs['embedding'] = embeddings

# %%
query = 'How many users does ChatGPT have?'
query_embedding = get_contriever_embedding([query])[0]

# %%
best_idx = paragraphs['embedding'].map(
    lambda emb: np.dot(emb, query_embedding) / (
        np.linalg.norm(emb) * np.linalg.norm(query_embedding)
    )
).argmax()

best_paragraph = paragraphs.iloc[best_idx]['paragraph']

# %%
best_paragraph
# Out:
# 'The potential of AI tools like ChatGPT creates a similar dilemma — should companies license large language models without modifications, or customize them and pay much higher usage rates?'

# %%
contriever_scores = paragraphs['embedding'].map(lambda emb: calc_contriever_score(emb, query_embedding))

# %%
paragraphs[(contriever_scores > 0.4)]
# Out:
#       index                                                url  \
# 55        3  https://techcrunch.com/2023/01/31/daily-crunch...
# 57        4  https://techcrunch.com/2023/01/31/openai-relea...
# 58        4  https://techcrunch.com/2023/01/31/openai-relea...
# 62        4  https://techcrunch.com/2023/01/31/openai-relea...
# 494      31  https://techcrunch.com/2023/01/30/rewinds-new-...
# 812      58  https://techcrunch.com/2023/01/27/best-twitter...
# 815      58  https://techcrunch.com/2023/01/27/best-twitter...
# 829      58  https://techcrunch.com/2023/01/27/best-twitter...
# 875      63  https://techcrunch.com/2023/01/27/techcrunch-r...
# 945      67  https://techcrunch.com/2023/01/27/the-current-...
# 1023     74  https://techcrunch.com/2023/01/26/hands-on-wit...
# 1165     82  https://techcrunch.com/2023/01/26/substack-int...
#
#                                               paragraph  \
# 55    Meanwhile, Rita ponders what would happen if C...
# 57    As the fervor around generative AI — particula...
# 58    OpenAI’s classifier — aptly called OpenAI AI T...
# 62    Out of curiosity, I fed some text through the ...
# 494   For a bit of fun, the app leveraged ChatGPT to...
# 812   Discord doesn’t really work like Twitter at al...
# 815   The downside is that Discord is more about cha...
# 829   We’ll keep this list updated as we explore new...
# 875   The potential of AI tools like ChatGPT creates...
# 945   Companies like Stability AI and OpenAI, the co...
# 1023  In theory, chat-based shopping is supposed to ...
# 1165  As for the other new Substack features rolling...
#
#                                               embedding
# 55    [-0.027771467342972755, -0.08329060673713684, ...
# 57    [0.0299002043902874, -0.12141577154397964, 0.0...
# 58    [-0.0034281201660633087, -0.026922766119241714...
# 62    [-0.0027712653391063213, 3.058241054532118e-05...
# 494   [-0.05853530392050743, -0.11826053261756897, 0...
# 812   [-0.0696338340640068, -0.041346512734889984, -...
# 815   [-0.04414699971675873, -0.11405253410339355, 0...
# 829   [-0.022291801869869232, -0.07762783020734787, ...
# 875   [0.015728451311588287, -0.06545095145702362, 0...
# 945   [-0.059773217886686325, -0.06636650115251541, ...
# 1023  [-0.0002533519291318953, -0.07816418260335922,...
# 1165  [0.0558038055896759, -0.08722010999917984, -0....

# %%
paragraphs.iloc[1213]
# Out:
# index                                                       87
# url          https://techcrunch.com/2023/01/26/nea-now-mana...
# paragraph    On one more note about LPs, Sandell shut down ...
# embedding    [0.011584528721868992, -0.052937474101781845, ...
# Name: 1213, dtype: object

# %%
paragraphs[paragraphs['paragraph'].str.startswith('Since')]
# Out:
#       index                                                url  \
# 62        4  https://techcrunch.com/2023/01/31/energy-x-sec...
# 263      21  https://techcrunch.com/2023/01/30/secai-marche...
# 796      58  https://techcrunch.com/2023/01/27/best-twitter...
# 849      63  https://techcrunch.com/2023/01/27/techcrunch-r...
# 1384    106  https://techcrunch.com/2023/01/25/apparel-desi...
# 1492    115  https://techcrunch.com/2023/01/24/japans-terra...
# 1559    123  https://techcrunch.com/2023/01/24/all-raise-ce...
# 1678    130  https://techcrunch.com/2023/01/24/alexa-funds-...
# 2239    180  https://techcrunch.com/2023/01/20/a-new-kind-o...
# 3072    253  https://techcrunch.com/2023/01/16/twitters-thi...
# 3082    253  https://techcrunch.com/2023/01/16/twitters-thi...
# 3632    293  https://techcrunch.com/2023/01/12/third-party-...
# 3791    306  https://techcrunch.com/2023/01/12/twitter-riva...
#
#                                               paragraph
# 62    Since its inception in 2019, the startup says ...
# 263   Since its seed funding, Secai Marche has built...
# 796   Since Cohost is fairly new and a bit rocky, it...
# 849   Since most startups are not AI businesses, his...
# 1384  Since January 6, a database containing hundred...
# 1492  Since its last fundraising, its subsidiaries’ ...
# 1559  Since launch, the nonprofit has raised $11 mil...
# 1678  Since the Alexa fund was created under Jeff Be...
# 2239  Since its foundation in 2019, FLEX Capital has...
# 3072  Since the beginning of the saga, many develope...
# 3082  Since Musk took over Twitter last year, the co...
# 3632  Since Elon Musk’s takeover, Twitter has killed...
# 3791  Since that early public commitment, T2, based ...

# %% [markdown]
# ## Hillary

# %%
emails_path = '/home/hackathon_2023/data/hillary_clinton_emails/data/Emails.csv'

# %%
emails = pd.read_csv(emails_path)

# %%
emails
# Out:
#         Id  DocNumber                                    MetadataSubject  \
# 0        1  C05739545                                                WOW
# 1        2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2        3  C05739547                                      CHRIS STEVENS
# 3        4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4        5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# ...    ...        ...                                                ...
# 7940  7941  C05778462                                              WYDEN
# 7941  7942  C05778463                                             SENATE
# 7942  7943  C05778465                                      RICHARD (TNR)
# 7943  7944  C05778466                                              FROM
# 7944  7945  C05778470                         NOTE FOR SECRETARY CLINTON
#
#         MetadataTo       MetadataFrom  SenderPersonId  \
# 0                H  Sullivan, Jacob J            87.0
# 1                H                NaN             NaN
# 2               ;H    Mills, Cheryl D            32.0
# 3                H    Mills, Cheryl D            32.0
# 4     Abedin, Huma                  H            80.0
# ...            ...                ...             ...
# 7940             H   Verma, Richard R           180.0
# 7941             H   Verma, Richard R           180.0
# 7942             H   Jiloty, Lauren C           116.0
# 7943             H           PVerveer           143.0
# 7944             H  Sullivan, Jacob J            87.0
#
#                MetadataDateSent       MetadataDateReleased  \
# 0     2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 1     2011-03-03T05:00:00+00:00  2015-05-22T04:00:00+00:00
# 2     2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 3     2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 4     2011-03-11T05:00:00+00:00  2015-05-22T04:00:00+00:00
# ...                         ...                        ...
# 7940  2010-12-16T05:00:00+00:00  2015-08-31T04:00:00+00:00
# 7941  2010-12-16T05:00:00+00:00  2015-08-31T04:00:00+00:00
# 7942  2010-12-16T05:00:00+00:00  2015-08-31T04:00:00+00:00
# 7943  2012-12-17T05:00:00+00:00  2015-08-31T04:00:00+00:00
# 7944  2010-12-17T05:00:00+00:00  2015-08-31T04:00:00+00:00
#
#                                         MetadataPdfLink MetadataCaseNumber  \
# 0     DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841
# 1     DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841
# 2     DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841
# 3     DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739550...       F-2015-04841
# 4     DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739554...       F-2015-04841
# ...                                                 ...                ...
# 7940  DOCUMENTS/HRCEmail_August_Web/IPS-0113/DOC_0C0...       F-2014-20439
# 7941  DOCUMENTS/HRCEmail_August_Web/IPS-0113/DOC_0C0...       F-2014-20439
# 7942  DOCUMENTS/HRCEmail_August_Web/IPS-0113/DOC_0C0...       F-2014-20439
# 7943  DOCUMENTS/HRCEmail_August_Web/IPS-0113/DOC_0C0...       F-2014-20439
# 7944  DOCUMENTS/HRCEmail_August_Web/IPS-0113/DOC_0C0...       F-2014-20439
#
#       ... ExtractedTo                             ExtractedFrom  \
# 0     ...         NaN  Sullivan, Jacob J <Sullivan11@state.gov>
# 1     ...         NaN                                       NaN
# 2     ...          B6       Mills, Cheryl D <MillsCD@state.gov>
# 3     ...         NaN       Mills, Cheryl D <MillsCD@state.gov>
# 4     ...         NaN                                       NaN
# ...   ...         ...                                       ...
# 7940  ...         NaN      Verma, Richard R <VermaRR@state.gov>
# 7941  ...         NaN      Verma, Richard R <VermaRR@state.gov>
# 7942  ...         NaN     Jiloty, Lauren C <JilotyLC@state.gov>
# 7943  ...    PVervee,                                       NaN
# 7944  ...         NaN  Sullivan, Jacob J <SullivanJJ@state.gov>
#
#                                            ExtractedCc  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                         Abedin, Huma
# 3                                   Mitchell, Andrew B
# 4                                                  NaN
# ...                                                ...
# 7940                                               NaN
# 7941  Sullivan, Jacob J; Mills, Cheryl D; Abedin, Huma
# 7942                                               NaN
# 7943                                               NaN
# 7944                                      Abedin, Huma
#
#                            ExtractedDateSent ExtractedCaseNumber  \
# 0     Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 1                                        NaN        F-2015-04841
# 2     Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 3      Wednesday, September 12,2012 12:44 PM        F-2015-04841
# 4                                        NaN        F-2015-04841
# ...                                      ...                 ...
# 7940     Thursday, December 16, 2010 7:41 PM        F-2014-20439
# 7941     Thursday, December 16, 2010 8:09 PM        F-2014-20439
# 7942    Thursday, December 16, 2010 10:52 PM        F-2014-20439
# 7943                               12/14/201        F-2014-20439
# 7944      Friday, December 17, 2010 10:42 AM        F-2014-20439
#
#      ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 0             C05739545            05/13/2015              RELEASE IN FULL
# 1             C05739546            05/13/2015              RELEASE IN PART
# 2             C05739547            05/14/2015              RELEASE IN PART
# 3             C05739550            05/13/2015              RELEASE IN PART
# 4             C05739554            05/13/2015              RELEASE IN PART
# ...                 ...                   ...                          ...
# 7940          C05778462            08/31/2015              RELEASE IN PART
# 7941          C05778463            08/31/2015              RELEASE IN FULL
# 7942          C05778465            08/31/2015              RELEASE IN PART
# 7943          C05778466            08/31/2015              RELEASE IN PART
# 7944          C05778470            08/31/2015              RELEASE IN FULL
#
#                                       ExtractedBodyText  \
# 0                                                   NaN
# 1     B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 2                                                   Thx
# 3                                                   NaN
# 4     H <hrod17@clintonemail.com>\nFriday, March 11,...
# ...                                                 ...
# 7940                                                NaN
# 7941  Big change of plans in the Senate. Senator Rei...
# 7942                                                NaN
# 7943  PVerveer B6\nFriday, December 17, 2010 12:12 A...
# 7944                                         See below.
#
#                                                 RawText
# 0     UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1     UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2     UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3     UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4     B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
# ...                                                 ...
# 7940  UNCLASSIFIED U.S. Department of State Case No....
# 7941  UNCLASSIFIED U.S. Department of State Case No....
# 7942  UNCLASSIFIED U.S. Department of State Case No....
# 7943  Hi dear Melanne and Alyse,\nHope this email re...
# 7944  UNCLASSIFIED U.S. Department of State Case No....
#
# [7945 rows x 22 columns]

# %%
mail_raw_text2paragraphs(raw_text1)[8]
# Out:
# "The Syrian soldiers in Libya are part of a mission established in 1984 following the signing of a military agreement between Qaddafi and Syria's long-time ruler and Bashir's father, Hafez al- Assad, in the presence of General Soubhi Haddad, who was the commander in chief of the Air Force at the time. Both Air Forces are equipped with Russian materiel and have had long- standing, close links with Moscow."

# %%
hl = HillaryEmails()
# Out:
# Some weights of the model checkpoint at facebook/contriever were not used when initializing Contriever: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing Contriever from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Contriever from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
paragraphs = hl.get_paragraphs()

# %%
paragraphs
# Out:
#       DocNumber                                            RawText  \
# 0     C05739545  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1     C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1     C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1     C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1     C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# ...         ...                                                ...
# 7942  C05778465  UNCLASSIFIED U.S. Department of State Case No....
# 7943  C05778466  Hi dear Melanne and Alyse,\nHope this email re...
# 7943  C05778466  Hi dear Melanne and Alyse,\nHope this email re...
# 7944  C05778470  UNCLASSIFIED U.S. Department of State Case No....
# 7944  C05778470  UNCLASSIFIED U.S. Department of State Case No....
#
#                                              paragraphs
# 0     What a wonderful, strong and moving statement ...
# 1     H: Latest How Syria is aiding Qaddafi and more...
# 1     hrc memo syria aiding libya 030311.docx; hrc m...
# 1     This memo has two parts. Part one is the repor...
# 1     During the afternoon of March 3, advisers to M...
# ...                                                 ...
# 7942  Source URL: http://www.tnr.com/article/79956/r...
# 7943          Hope this email reaches you at good time.
# 7943  let me know if I can be of any help to your de...
# 7944  The outpouring of condolences from the interna...
# 7944  Separately, I would ask that you thank Mike Mu...
#
# [42236 rows x 3 columns]

# %%
hl.add_embedding()
# Out:
# 100% 423/423 [1:22:27<00:00, 11.70s/it]

# %%
fea_save_path = '/home/hackathon_2023/ron/hillary_paragraph_embedded.fea'
hl.emails_paragraphs.reset_index().to_feather(fea_save_path)

# %%
pargraphs = pd.read_feather(fea_save_path)

# %%
pargraphs
# Out:
#        index  DocNumber                                            RawText  \
# 0          0  C05739545  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1          1  C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2          1  C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3          1  C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4          1  C05739546  UNCLASSIFIED\nU.S. Department of State\nCase N...
# ...      ...        ...                                                ...
# 42231   7942  C05778465  UNCLASSIFIED U.S. Department of State Case No....
# 42232   7943  C05778466  Hi dear Melanne and Alyse,\nHope this email re...
# 42233   7943  C05778466  Hi dear Melanne and Alyse,\nHope this email re...
# 42234   7944  C05778470  UNCLASSIFIED U.S. Department of State Case No....
# 42235   7944  C05778470  UNCLASSIFIED U.S. Department of State Case No....
#
#                                               paragraphs  \
# 0      What a wonderful, strong and moving statement ...
# 1      H: Latest How Syria is aiding Qaddafi and more...
# 2      hrc memo syria aiding libya 030311.docx; hrc m...
# 3      This memo has two parts. Part one is the repor...
# 4      During the afternoon of March 3, advisers to M...
# ...                                                  ...
# 42231  Source URL: http://www.tnr.com/article/79956/r...
# 42232          Hope this email reaches you at good time.
# 42233  let me know if I can be of any help to your de...
# 42234  The outpouring of condolences from the interna...
# 42235  Separately, I would ask that you thank Mike Mu...
#
#                                                embedding
# 0      [0.021930361166596413, -0.021510425955057144, ...
# 1      [-0.0028949459083378315, 0.003931017126888037,...
# 2      [-0.005725331604480743, -0.03571368753910065, ...
# 3      [0.0843600481748581, 0.08511161804199219, -0.0...
# 4      [0.05619313567876816, -0.01754940114915371, -0...
# ...                                                  ...
# 42231  [0.009207452647387981, 0.02946539968252182, -0...
# 42232  [-0.037801507860422134, -0.0005279278266243637...
# 42233  [-0.06297259032726288, 0.018239501863718033, 0...
# 42234  [0.1036808043718338, 6.542534720210824e-06, -0...
# 42235  [0.04182538762688637, 0.12138251215219498, -0....
#
# [42236 rows x 5 columns]

# %% [markdown]
# ## Queries

# %%
hqs = HillaryQueryScore()

# %%
query = 'Benghazi attack'

query_scores = hqs.get_query_scores(query)
query_scores
# Out:
#        index  DocNumber                                            RawText  \
# 2373     227  C05739826  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2028     202  C05739798  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1788     166  C05739757  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 36         6  C05739560  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 502       52  C05739623  UNCLASSIFIED\nU.S. Department of State\nCase N...
# ...      ...        ...                                                ...
# 28012   5284  C05769949  UNCLASSIFIED U.S. Department of State Case No....
# 41274   7718  C05775819  UNCLASSIFIED U.S. Department of State Case No....
# 25787   4860  C05769080  UNCLASSIFIED U.S. Department of State Case No....
# 6793    1359  C05760796  UNCLASSIFIED U.S. Department of State Case No....
# 38153   7083  C05773954  UNCLASSIFIED U.S. Department of State Case No....
#
#                                               paragraphs  \
# 2373   on the successful Benghazi attack, or launchin...
# 2028   Libyans march against Islamist militias in Ben...
# 1788   Libyans march against Islamist militias in Ben...
# 36     Ambassador J. Christopher Stevens and three ot...
# 502     Libya attack to paint Obama as weak on terrorism
# ...                                                  ...
# 28012  The core goals of the Arenga Reforestation Pro...
# 41274  The core goals of the Arenga Reforestation Pro...
# 25787  1171:n70.1134041:=2:147.:MTY:71,32'W...arinTWA...
# 6793   It is this conviction that drove Domenici, who...
# 38153  As for Mr. Jagger, the complaints are deep-sea...
#
#                                                embedding     score
# 2373   [-0.030353069305419922, -0.032487206161022186,...  0.721530
# 2028   [0.03709092363715172, -0.00034611611044965684,...  0.704742
# 1788   [0.03709092363715172, -0.00034611611044965684,...  0.704742
# 36     [-0.019471045583486557, -0.07690425217151642, ...  0.689470
# 502    [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# ...                                                  ...       ...
# 28012  [-0.021177805960178375, -0.08578544110059738, ...  0.125444
# 41274  [-0.021177805960178375, -0.08578544110059738, ...  0.125444
# 25787  [0.0834178626537323, 0.02872912585735321, -0.0...  0.120128
# 6793   [-0.061600152403116226, 0.09540513902902603, -...  0.119166
# 38153  [-0.04557671397924423, 0.011483922600746155, -...  0.117211
#
# [42236 rows x 6 columns]

# %%
query_scores.iloc[:10]
# Out:
#       index  DocNumber                                            RawText  \
# 2373    227  C05739826  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2028    202  C05739798  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1788    166  C05739757  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 36        6  C05739560  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 502      52  C05739623  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 567      57  C05739629  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 534      55  C05739627  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 446      46  C05739615  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
# 465      48  C05739618  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 484      50  C05739620  UNCLASSIFIED\nU.S. Department of State\nCase N...
#
#                                              paragraphs  \
# 2373  on the successful Benghazi attack, or launchin...
# 2028  Libyans march against Islamist militias in Ben...
# 1788  Libyans march against Islamist militias in Ben...
# 36    Ambassador J. Christopher Stevens and three ot...
# 502    Libya attack to paint Obama as weak on terrorism
# 567    Libya attack to paint Obama as weak on terrorism
# 534    Libya attack to paint Obama as weak on terrorism
# 446    Libya attack to paint Obama as weak on terrorism
# 465    Libya attack to paint Obama as weak on terrorism
# 484    Libya attack to paint Obama as weak on terrorism
#
#                                               embedding     score
# 2373  [-0.030353069305419922, -0.032487206161022186,...  0.721530
# 2028  [0.03709092363715172, -0.00034611611044965684,...  0.704742
# 1788  [0.03709092363715172, -0.00034611611044965684,...  0.704742
# 36    [-0.019471045583486557, -0.07690425217151642, ...  0.689470
# 502   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 567   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 534   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 446   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 465   [-0.03538616746664047, -0.011815848760306835, ...  0.673741
# 484   [-0.03538616746664047, -0.011815848760306835, ...  0.673741

# %%
print(query_scores.iloc[9]['paragraphs'])
# Out:
# Libya attack to paint Obama as weak on terrorism

# %%
query = 'receipt over work'

query_scores = hqs.get_query_scores(query)
query_scores.iloc[:10]
# Out:
#        index  DocNumber                                            RawText  \
# 12821   2347  C05763223  UNCLASSIFIED U.S. Department of State Case No....
# 12832   2347  C05763223  UNCLASSIFIED U.S. Department of State Case No....
# 9856    1860  C05762308  UNCLASSIFIED U.S. Department of State Case No....
# 32399   6161  C05771617  UNCLASSIFIED U.S. Department of State Case No....
# 32427   6164  C05771621  UNCLASSIFIED U.S. Department of State Case No....
# 12972   2347  C05763223  UNCLASSIFIED U.S. Department of State Case No....
# 9768    1860  C05762308  UNCLASSIFIED U.S. Department of State Case No....
# 12792   2347  C05763223  UNCLASSIFIED U.S. Department of State Case No....
# 13227   2347  C05763223  UNCLASSIFIED U.S. Department of State Case No....
# 18415   3423  C05766021  UNCLASSIFIED U.S. Department of State Case No....
#
#                                               paragraphs  \
# 12821            6 employee would have been entitled had
# 12832  19 that no employee of the Office may receive ...
# 9856                Lawsuits against abusive contractors
# 32399  attorney/client communications or work product...
# 32427  attorney/client communications or work product...
# 12972  19 employees for any provision of law administ...
# 9768               the committee members' work "would be
# 12792  22 pose of preserving such employee's allowances,
# 13227  18 velopment on a reimbursable basis. Any empl...
# 18415    ATTORNEY-CLIENT PRIVILEGE/ATTORNEY WORK-PRODUCT
#
#                                                embedding     score
# 12821  [0.01179588958621025, -0.007500728126615286, -...  0.416572
# 12832  [0.03442981839179993, 0.10039772093296051, -0....  0.390957
# 9856   [-0.02425953559577465, -0.0375225804746151, -0...  0.383827
# 32399  [-0.09112697094678879, -0.008438197895884514, ...  0.381435
# 32427  [-0.09112697094678879, -0.008438197895884514, ...  0.381435
# 12972  [-0.0526542030274868, 0.03969474136829376, -0....  0.380533
# 9768   [-0.013876518234610558, 0.030208135023713112, ...  0.378028
# 12792  [0.015126695856451988, 0.04493490979075432, -0...  0.377528
# 13227  [-0.09702442586421967, 0.010156353935599327, -...  0.375811
# 18415  [-0.04743870347738266, 0.0212693028151989, 0.0...  0.373973

# %%
print(query_scores.iloc[2]['paragraphs'])
# Out:
# Iran provides 14 percent of China's demand for oil.
